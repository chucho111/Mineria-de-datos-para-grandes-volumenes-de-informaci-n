# %% [markdown]
# # Instalación de librerias.

# %%
# !pip install boto3
# Out:
# ...
#      |████████████████████████████████| 133kB 2.8MB/s
# ...
#      |████████████████████████████████| 81kB 6.8MB/s
# ...
#      |████████████████████████████████| 7.6MB 11.2MB/s
# ...
#      |████████████████████████████████| 143kB 34.4MB/s
# ...
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.5 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %% [markdown]
# # Activo la libreria de drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Descarga del dataset.

# %%
import boto3
aws_access_key_id_='ASIAUCWHHMVEENJDLXUP'
aws_secret_access_key_='YQsQ1r22dTUVl86/GEbKpc60F7nPixpIWZXyw5Vy'
aws_session_token_='...'
# Crea s3.cliente y s3.recurso
bucket_name = 'agriculture-vision-analitics' 
# enter authentication credentials
access_key_id=aws_access_key_id_
secret_access_key=aws_secret_access_key_
session_token=aws_session_token_
resource = boto3.resource('s3', aws_access_key_id = access_key_id, aws_secret_access_key = secret_access_key, aws_session_token = session_token)
client = boto3.client("s3", aws_access_key_id = access_key_id, aws_secret_access_key = secret_access_key, aws_session_token = session_token)

# %%
# En forma de directorio mineria.
client.download_file(bucket_name, 'dataset-mineria.tar.gz', '/content/drive/MyDrive/AgricultureVisión/Data/dataset-mineria.tar.gz')

# %%
# En forma de tfrecords mineria.
client.download_file(bucket_name, 'dataset-mineria-complete-tfrecord.tar.gz', '/content/drive/MyDrive/AgricultureVisión/Data/dataset-mineria-complete-tfrecord.tar.gz')

# %%
# En forma de directorio estadistica.
client.download_file(bucket_name, 'dataset-mineria.tar.gz', '/content/drive/MyDrive/AgricultureVisión/Data/dataset-estadistica.tar.gz')

# %%
# En forma de tfrecords estadistica.
client.download_file(bucket_name, 'dataset-mineria-complete-tfrecord.tar.gz', '/content/drive/MyDrive/AgricultureVisión/Data/dataset-estadistica-tfrecord.tar.gz')

# %% [markdown]
# # Descomprimo los archivos .tar.gz.

# %%
! tar -xzvf /content/drive/MyDrive/AgricultureVisión/Data/dataset-mineria/rgb.tar.gz --directory /content/drive/MyDrive/AgricultureVisión/Data/dataset-mineria/train/
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# rgb/weed_cluster/LLKUGCFKV_2003-3190-2515-3702.jpg
# rgb/weed_cluster/LLKUGCFKV_2100-2314-2612-2826.jpg
# rgb/weed_cluster/LLKUGCFKV_2182-747-2694-1259.jpg
# rgb/weed_cluster/LLKUGCFKV_2311-1110-2823-1622.jpg
# rgb/weed_cluster/LLKUGCFKV_3262-1718-3774-2230.jpg
# rgb/weed_cluster/LLKUGCFKV_3733-1447-4245-1959.jpg
# rgb/weed_cluster/LLKUGCFKV_3733-1959-4245-2471.jpg
# rgb/weed_cluster/LLKUGCFKV_3733-2471-4245-2983.jpg
# rgb/weed_cluster/LLKUGCFKV_3733-2983-4245-3495.jpg
# rgb/weed_cluster/LLKUGCFKV_3733-935-4245-1447.jpg
# rgb/weed_cluster/LLKUGCFKV_4025-912-4537-1424.jpg
# rgb/weed_cluster/LLKUGCFKV_4067-2724-4579-3236.jpg
# rgb/weed_cluster/LLKUGCFKV_4075-3227-4587-3739.jpg
# rgb/weed_cluster/LLKUGCFKV_4075-3739-4587-4251.jpg
# rgb/weed_cluster/LLKUGCFKV_4110-4204-4622-4716.jpg
# rgb/weed_cluster/LLKUGCFKV_4245-1447-4757-1959.jpg
# rgb/weed_cluster/LLKUGCFKV_4245-1959-4757-2471.jpg
# ...

# %%
! tar -xzvf /content/drive/MyDrive/AgricultureVisión/Data/dataset-mineria.tar.gz --directory /content/drive/MyDrive/AgricultureVisión/Data/
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# dataset-mineria/train/bounds/nutrient_deficiency/EXHQ8CU4B_7359-5217-7871-5729.png
# dataset-mineria/train/bounds/nutrient_deficiency/2FUYE4ID8_4035-7999-4547-8511.png
# dataset-mineria/train/bounds/nutrient_deficiency/6XK1QLCDN_781-8220-1293-8732.png
# dataset-mineria/train/bounds/nutrient_deficiency/2MLICNC7Z_9437-7732-9949-8244.png
# dataset-mineria/train/bounds/nutrient_deficiency/E4ZCFL7MU_4425-7688-4937-8200.png
# dataset-mineria/train/bounds/nutrient_deficiency/GAEF1FZBT_3856-2256-4368-2768.png
# dataset-mineria/train/bounds/nutrient_deficiency/8U6TJWBGD_5008-5800-5520-6312.png
# dataset-mineria/train/bounds/nutrient_deficiency/F67NZQZVK_1399-1967-1911-2479.png
# dataset-mineria/train/bounds/nutrient_deficiency/AX6BB2HH2_4295-1946-4807-2458.png
# dataset-mineria/train/bounds/nutrient_deficiency/PNT3A28LP_6765-2823-7277-3335.png
# dataset-mineria/train/bounds/nutrient_deficiency/RTKKF8T8R_1570-7954-2082-8466.png
# ...

# %%
! tar -xzvf /content/drive/MyDrive/AgricultureVisión/Data/dataset-mineria-complete-tfrecord.tar.gz --directory /content/drive/MyDrive/AgricultureVisión/Data/

# %%
! tar -xzvf /content/drive/MyDrive/AgricultureVisión/Data/dataset-estadistica.tar.gz --directory /content/drive/MyDrive/AgricultureVisión/Data/

# %%
! tar -xzvf /content/drive/MyDrive/AgricultureVisión/Data/dataset-estadistica-tfrecord.tar.gz --directory /content/drive/MyDrive/AgricultureVisión/Data/

# %%
ls /content/drive/MyDrive/AgricultureVisión/Data/dataset-mineria/train/rgb/double_plant
# Out:
# 11IE4DKTR_11556-9586-12068-10098.jpg   HEH22TCTL_11878-7754-12390-8266.jpg
# 11IE4DKTR_6121-684-6633-1196.jpg       HEH22TCTL_11878-8266-12390-8778.jpg
# 11TAQJ6ET_1124-8510-1636-9022.jpg      HEH22TCTL_11965-5002-12477-5514.jpg
# 11TAQJ6ET_1148-8089-1660-8601.jpg      HEH22TCTL_11969-13774-12481-14286.jpg
# 11TAQJ6ET_1288-961-1800-1473.jpg       HEH22TCTL_12116-842-12628-1354.jpg
# 11TAQJ6ET_1422-8427-1934-8939.jpg      HEH22TCTL_12162-6522-12674-7034.jpg
# 11TAQJ6ET_1567-8177-2079-8689.jpg      HEH22TCTL_12168-8073-12680-8585.jpg
# 11TAQJ6ET_1749-948-2261-1460.jpg       HEH22TCTL_12250-10034-12762-10546.jpg
# 11TAQJ6ET_1995-8426-2507-8938.jpg      HEH22TCTL_12342-9699-12854-10211.jpg
# 11TAQJ6ET_2034-926-2546-1438.jpg       HEH22TCTL_12372-10261-12884-10773.jpg
# 11TAQJ6ET_2172-7065-2684-7577.jpg      HEH22TCTL_2760-9798-3272-10310.jpg
# 11TAQJ6ET_2172-8089-2684-8601.jpg      HEH22TCTL_3437-13462-3949-13974.jpg
# ...
